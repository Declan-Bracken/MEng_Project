# %%
import pandas as pd

data = {
    'course_code': [
        # Standard Course Codes
        'CJ 341 Police Meth & Org', 'FSC 440 Drug Identification', 'FSC 440L Drug Id Lab',
        'FSC 442 Arson And Explosive', 'FSC 497CA Field Study', 'PHY 111 General Physics I',
        'PHY 111L Gen Phy I Lab',

        # Course Codes with Special Characters
        '020ANGNI1 Analyse Générale', '020CHGNI1 Chimie Générale', 
        '020GCCNI1 Le Génie Civil au Service de la Communauté', 
        '020MADNI1 Mathématiques Discrètes', '020MC1NI1 Mécanique 1', 
        '020SPHNI1 Signaux Physiques',

        # Alphanumeric Course Codes
        'ANT100Y1 Intro Anthropology', 'CSC108H1 Intro to Comp Prog', 
        'ECO100Y1 Intro Economics', 'MAT137Y1 Calculus!',

        # No Spaces in Course Codes
        'MECH128', 'CSE101', 'MATH402', 'BIO50A', 'ENG99',

        # Hyphen-separated Course Codes
        'MECH-128', 'CSE-101', 'MATH-402', 'BIO-50A', 'ENG-99',

        # Reversed Course Code Order
        '128 MECH', '101 CSE', '402 MATH', '50A BIO', '99 ENG',

        # Mixed Course Codes and Titles
        'MECH 128 Mechanical Engineering', 'Introduction to Computing CSE 101', 
        'Advanced Calculus MATH 402', 'BIO 50A Biology', 'ENG 99 English Literature',

        # Course Titles Only
        'Mechanical Engineering', 'Introduction to Computing', 
        'Advanced Calculus', 'Biology', 'English Literature',

        # Mixed Tokens with Hyphens
        'MECH-128-Mechanical', 'CSE-101-Computing', 'MATH-402-Calculus', 
        'BIO-50A-Biology', 'ENG-99-English',

        # Mixed Alphanumeric Course Codes
        'MECH128A', 'CSE101B', 'MATH402C', 'BIO50D', 'ENG99E',

        # Empty Course Code Entries
        'MECH 128', '', 'MATH 402', None, 'ENG 99'
    ],
    'labels': [
        # Standard Course Codes
        'CJ [DEPT] 341 [NUM]', 'FSC [DEPT] 440 [NUM]', 'FSC [DEPT] 440L [NUM]',
        'FSC [DEPT] 442 [NUM]', 'FSC [DEPT] 497CA [NUM]', 'PHY [DEPT] 111 [NUM]',
        'PHY [DEPT] 111L [NUM]',

        # Course Codes with Special Characters
        '020ANGNI1 [DEPT]', '020CHGNI1 [DEPT]', 
        '020GCCNI1 [DEPT]', '020MADNI1 [DEPT]', '020MC1NI1 [DEPT] 1 [NUM]', 
        '020SPHNI1 [DEPT]',

        # Alphanumeric Course Codes
        'ANT [DEPT] 100 [NUM] Y1', 'CSC [DEPT] 108 [NUM] H1', 
        'ECO [DEPT] 100 [NUM] Y1', 'MAT [DEPT] 137 [NUM] Y1',

        # No Spaces in Course Codes
        'MECH [DEPT] 128 [NUM]', 'CSE [DEPT] 101 [NUM]', 'MATH [DEPT] 402 [NUM]', 
        'BIO [DEPT] 50A [NUM]', 'ENG [DEPT] 99 [NUM]',

        # Hyphen-separated Course Codes
        'MECH [DEPT] 128 [NUM]', 'CSE [DEPT] 101 [NUM]', 'MATH [DEPT] 402 [NUM]', 
        'BIO [DEPT] 50A [NUM]', 'ENG [DEPT] 99 [NUM]',

        # Reversed Course Code Order
        '128 [NUM] MECH [DEPT]', '101 [NUM] CSE [DEPT]', '402 [NUM] MATH [DEPT]', 
        '50A [NUM] BIO [DEPT]', '99 [NUM] ENG [DEPT]',

        # Mixed Course Codes and Titles
        'MECH [DEPT] 128 [NUM]', 'CSE [DEPT] 101 [NUM]', 
        'MATH [DEPT] 402 [NUM]', 'BIO [DEPT] 50A [NUM]', 'ENG [DEPT] 99 [NUM]',

        # Course Titles Only
        'Mechanical [DEPT]', 'Computing [DEPT]', 
        'Calculus [DEPT]', 'Biology [DEPT]', 'Literature [DEPT]',

        # Mixed Tokens with Hyphens
        'MECH [DEPT] 128 [NUM]', 'CSE [DEPT] 101 [NUM]', 'MATH [DEPT] 402 [NUM]', 
        'BIO [DEPT] 50A [NUM]', 'ENG [DEPT] 99 [NUM]',

        # Mixed Alphanumeric Course Codes
        'MECH [DEPT] 128 [NUM] A', 'CSE [DEPT] 101 [NUM] B', 'MATH [DEPT] 402 [NUM] C', 
        'BIO [DEPT] 50 [NUM] D', 'ENG [DEPT] 99 [NUM] E',

        # Empty Course Code Entries
        'MECH [DEPT] 128 [NUM]', '', 'MATH [DEPT] 402 [NUM]', None, 'ENG [DEPT] 99 [NUM]'
    ]
}

df = pd.DataFrame(data)
df.to_csv('extended_dataset.csv', index=False)

# %%
import pandas as pd

data = {
    'course_code': [
        'WRDS 150B (3.0) Writing and Research in the Disciplines', 
        'PHIL 120 (3.0) Introduction to Critical Thinking',
        'CNPS 363 (3.0) Career Counselling',
        'CNPS 364 (3.0) Family Education and Consultation',
        'FRST 303 (3.0) Principles of Forest Science',
        'GERM 433 (3.0) German for Reading Knowledge I',
        'MATH 312 (3.0) Introduction to Number Theory',
        'EOSC 111 (1.0) Laboratory Exploration of Planet Earth',
        'MATH 210 (3.0) Introduction to Mathematical Computing',
        'MATH 309 (3.0) Topics in Geometry',
        'MATH 317 (3.0) Calculus IV',
        'PHIL 220A (3.0) Symbolic Logic',
        'CONS 127 (3.0) Observing the Earth from Space',
        'ASIA 330 (3.0) Islam in South Asia (1750 - present)',
        'STAT 306 (3.0) Finding Relationships in Data',
        'CNPS 427 (3.0) Guidance: Planning and Decision-making',
        'CNPS 433 (3.0) The Personal and Social Development of the Adult',
        'MATH 308 (3.0) Euclidean Geometry',
        'MATH 340 (3.0) Introduction to Linear Programming',
        'STAT 406 (3.0) Methods for Statistical Learning',
        'CPSC 110 (4.0) COMPTN PROGRMMG',
        'MATH 210 (3.0) Introduction to Mathematical Computing',
        'MATH 345 (3.0) Applied Nonlinear Dynamics and Chaos',
        'MATH 441 (3.0) Mathematical Modelling: Discrete Optimization Problems',
        'PHYS 119 (1.0) Experimental Physics Lab I',
        'COMM 101 (0.50) Introduction to Financial Markets',
        'CS 115 (0.50) Introduction to Computer Science 1',
        'EMLS 129R (0.50) Written Academic English',
        'MATH 135 (0.50) Algebra for Honours Mathematics',
        'MATH 137 (0.50) Calculus 1 for Honours Mathematics',
        'CS 116 (0.50) Introduction to Computer Science 2',
        'ECON 102 (0.50) Introduction to Macroeconomics',
        'MATH 136 (0.50) Linear Algebra 1 for Honours Mathematics',
        'MATH 138 (0.50) Calculus 2 for Honours Mathematics',
        'STAT 230 (0.50) Probability',
        'ECON 101 220 102 Economics: Microeconomics',
        'ECON 103 220 103 Economics: Macroeconomics',
        'CALC 151 640 151 Calculus AB Subscore Grade',
        'CALC 152 640 152 Calculus BC',
        'PHYS 203 750 203 Physics 1: Algebra Based',
        'PHYS 205 750 205 Physics 1: Algebra Based',
        'COMSCI 111 01 198 111 Intro Computer Sci',
        'RDNG 100 01 355 099 Reading for English 100',
        'BASICCOMP 101 01 355 099 Basic Composition',
        'LINEARALG 251 01 640 251 Intro Linear Algebra',
        'BUSINESS 108 33 011 108 Intro to Business',
        'RUFIT 1 33 011 124 RU-FIT',
        'COMM 2BC3 (3.0) HR Mngmt & Labour Relations',
        'COMM 2FB3 (3.0) Managerial Finance',
        'COMM 2GR0B (0.0) DeGroote Student Exper&Develop II',
        'COMM 2IN0 (0.0) Career Development Course',
        'COMM 2OC3 (3.0) Operations Management',
        'CITIZENSHIP',
        'FRESHMAN ENGLISH',
        'PE',
        'REFRESHER MATHEMATICS',
        'SPANISH I',
        'US HISTORY',
        'ADVANCED MATHEMATICS',
        'CIVICS',
        'FRESHMAN ENGLISH',
        'PE',
        'SPANISH I',
        'WORLD HISTORY I',
        'EARLY CIVILIZATION',
        'GEOMETRY',
        'PE',
        'SHOP: MECHANICAL DRAFTING',
        'SPANISH II',
        'WORLD HISTORY II',
        'ART: PAINTING',
        'BEGINNING CHEMISTRY',
        'PE',
        'SPANISH II',
        'WORLD LITERATURE',
        'WRITING SKILLS'
    ],
    'labels': [
        'WRDS [DEPT] 150B [NUM] (3.0)', 
        'PHIL [DEPT] 120 [NUM] (3.0)',
        'CNPS [DEPT] 363 [NUM] (3.0)',
        'CNPS [DEPT] 364 [NUM] (3.0)',
        'FRST [DEPT] 303 [NUM] (3.0)',
        'GERM [DEPT] 433 [NUM] (3.0)',
        'MATH [DEPT] 312 [NUM] (3.0)',
        'EOSC [DEPT] 111 [NUM] (1.0)',
        'MATH [DEPT] 210 [NUM] (3.0)',
        'MATH [DEPT] 309 [NUM] (3.0)',
        'MATH [DEPT] 317 [NUM] (3.0)',
        'PHIL [DEPT] 220A [NUM] (3.0)',
        'CONS [DEPT] 127 [NUM] (3.0)',
        'ASIA [DEPT] 330 [NUM] (3.0)',
        'STAT [DEPT] 306 [NUM] (3.0)',
        'CNPS [DEPT] 427 [NUM] (3.0)',
        'CNPS [DEPT] 433 [NUM] (3.0)',
        'MATH [DEPT] 308 [NUM] (3.0)',
        'MATH [DEPT] 340 [NUM] (3.0)',
        'STAT [DEPT] 406 [NUM] (3.0)',
        'CPSC [DEPT] 110 [NUM] (4.0)',
        'MATH [DEPT] 210 [NUM] (3.0)',
        'MATH [DEPT] 345 [NUM] (3.0)',
        'MATH [DEPT] 441 [NUM] (3.0)',
        'PHYS [DEPT] 119 [NUM] (1.0)',
        'COMM [DEPT] 101 [NUM] (0.50)',
        'CS [DEPT] 115 [NUM] (0.50)',
        'EMLS [DEPT] 129R [NUM] (0.50)',
        'MATH [DEPT] 135 [NUM] (0.50)',
        'MATH [DEPT] 137 [NUM] (0.50)',
        'CS [DEPT] 116 [NUM] (0.50)',
        'ECON [DEPT] 102 [NUM] (0.50)',
        'MATH [DEPT] 136 [NUM] (0.50)',
        'MATH [DEPT] 138 [NUM] (0.50)',
        'STAT [DEPT] 230 [NUM] (0.50)',
        'ECON [DEPT] 101 220 [NUM] 102 [NUM]',
        'ECON [DEPT] 103 220 [NUM] 103 [NUM]',
        'CALC [DEPT] 151 640 [NUM] 151 [NUM]',
        'CALC [DEPT] 152 640 [NUM] 152 [NUM]',
        'PHYS [DEPT] 203 750 [NUM] 203 [NUM]',
        'PHYS [DEPT] 205 750 [NUM] 205 [NUM]',
        'COMSCI [DEPT] 111 01 [NUM] 198 111 [NUM]',
        'RDNG [DEPT] 100 01 [NUM] 355 099 [NUM]',
        'BASICCOMP [DEPT] 101 01 [NUM] 355 099 [NUM]',
        'LINEARALG [DEPT] 251 01 [NUM] 640 251 [NUM]',
        'BUSINESS [DEPT] 108 33 [NUM] 011 108 [NUM]',
        'RUFIT [DEPT] 1 33 [NUM] 011 124 [NUM]',
        'COMM [DEPT] 2BC3 [NUM] (3.0)',
        'COMM [DEPT] 2FB3 [NUM] (3.0)',
        'COMM [DEPT] 2GR0B [NUM] (0.0)',
        'COMM [DEPT] 2IN0 [NUM] (0.0)',
        'COMM [DEPT] 2OC3 [NUM] (3.0)',
        'CITIZENSHIP',
        'FRESHMAN ENGLISH',
        'PE',
        'REFRESHER MATHEMATICS',
        'SPANISH I',
        'US HISTORY',
        'ADVANCED MATHEMATICS',
        'CIVICS',
        'FRESHMAN ENGLISH',
        'PE',
        'SPANISH I',
        'WORLD HISTORY I',
        'EARLY CIVILIZATION',
        'GEOMETRY',
        'PE',
        'SHOP: MECHANICAL DRAFTING',
        'SPANISH II',
        'WORLD HISTORY II',
        'ART: PAINTING',
        'BEGINNING CHEMISTRY',
        'PE',
        'SPANISH II',
        'WORLD LITERATURE',
        'WRITING SKILLS'
    ]
}

df = pd.DataFrame(data)
df.to_csv('extended_dataset.csv', index=False)
