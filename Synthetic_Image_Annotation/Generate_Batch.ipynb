# %%
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from google.auth.transport.requests import Request
import os


class GoogleDriveManager:
    def __init__(self, credentials_file='/Users/declanbracken/Development/UofT_Projects/Meng_Project/code_base/web_scraping/client_secret_809384080547-4sfr7l9u8a618keak7b11qan4o63nvh3.apps.googleusercontent.com.json', token_file='token.json', scopes=None):
        self.credentials_file = credentials_file
        self.token_file = token_file
        self.scopes = ['https://www.googleapis.com/auth/drive']
        self.service = self.authenticate_google_drive()

    def authenticate_google_drive(self):
        """Authenticate and return a Google Drive service object."""
        creds = None
        if os.path.exists(self.token_file):
            creds = Credentials.from_authorized_user_file(self.token_file, self.scopes)
        if not creds or not creds.valid:
            if creds and creds.expired and creds.refresh_token:
                creds.refresh(Request())
            else:
                flow = InstalledAppFlow.from_client_secrets_file(self.credentials_file, self.scopes)
                creds = flow.run_local_server(port=0)
            with open(self.token_file, 'w') as token:
                token.write(creds.to_json())
        return build('drive', 'v3', credentials=creds)
    
    def list_files_in_folder(self, folder_id):
        query = f"'{folder_id}' in parents and mimeType contains 'image/'"
        results = self.service.files().list(q=query, pageSize=1000, fields="nextPageToken, files(id, name)").execute()
        items = results.get('files', [])
        return items

    def get_file_urls(self, files):
        file_urls = []
        for file in files:
            file_id = file['id']
            file_url = f"https://drive.google.com/uc?id={file_id}"
            file_urls.append(file_url)
        return file_urls

# Path to your service account key file
SERVICE_ACCOUNT_FILE = '/Users/declanbracken/Development/UofT_Projects/Meng_Project/code_base/web_scraping/client_secret_809384080547-4sfr7l9u8a618keak7b11qan4o63nvh3.apps.googleusercontent.com.json'

# ID of the folder containing the images
FOLDER_ID = '14zyq0BXTYrYj81bGlKtYpEG-KL59oNnM'

# Create manager instace
manager = GoogleDriveManager(credentials_file=SERVICE_ACCOUNT_FILE)#, token_file=TOKEN_FILE)

# Get folder items
folder_items = manager.list_files_in_folder(FOLDER_ID)

# List urls
image_urls = manager.get_file_urls(folder_items)

# %%
# Print or use the list of image URLs
for url in image_urls:
    print(url)
# Out:
# https://drive.google.com/uc?id=1QrUWNZv5f7QFKjExPCF6gcso5jsmJYGq
# https://drive.google.com/uc?id=1M_8OgVIUafvwupnvRVkjCiFtw9F3LZ4R
# https://drive.google.com/uc?id=1SkhPNjaVKRTz4XGiEULl9ukwgqMTrVF-
# https://drive.google.com/uc?id=11u_oNNGCOSciEEgaefHkYLRDHSPUvVGz
# https://drive.google.com/uc?id=1a27GpxxEBqAL5X1QYcoHcenfaVLXyVgG
# https://drive.google.com/uc?id=17G7k-uJgDe94yGv4a99t4EUAtj463eMO
# https://drive.google.com/uc?id=1nw0Elt2qwdbg3tmHr9S7nKOIF65K7aN0
# https://drive.google.com/uc?id=1SOsmFJzIjcPx7vhHc2iH_ZcDk1Wz1MRv
# https://drive.google.com/uc?id=1NiNGMa_erAA75qmuN8EQxkhf_reWep5J
# https://drive.google.com/uc?id=1qC9yQaEJYELkosM2wv7VmDtyMLLwpZKR
# https://drive.google.com/uc?id=1PaxJGQ3egf1W2a-7pCsmdmqsVQBIJi7v
# https://drive.google.com/uc?id=1w0AuTOfeNgzQcQ10QeFcUsG5Z8nexSOc
# https://drive.google.com/uc?id=1dtMhvdMM9SPDA8iTtDg8HK4Lbhv7xN4m
# https://drive.google.com/uc?id=1ZRimkmpXljp-sYfOJDMd6RibjPjML69E
# https://drive.google.com/uc?id=1_1cGpVa8Dn8BY8AnhybCBQY-o-QbJmEI
# https://drive.google.com/uc?id=1WwYDf3a75X8kGY2MSqtzlUOWzyPj_djh
# https://drive.google.com/uc?id=1b5xz5UrpOuWfCEfJXrYujU5nmnihBRh6
# https://drive.google.com/uc?id=1ak0U4JeGTH9eXMuRW92l18ZxkZAQKQ1X
# https://drive.google.com/uc?id=10OfaxyxSRdy6Hxx-T_u3I40l7vtq-ju0
# https://drive.google.com/uc?id=1FR4WAPUbhlAGZOMacTpMvjr_zCKjZADt
# https://drive.google.com/uc?id=1ANYGDGNKBiVGhThTkCaa12-j6Dct6hHm
# https://drive.google.com/uc?id=15QNknzhnE5bXlBGpz7uoEb44x7YIJl-F
# https://drive.google.com/uc?id=1w6lTeidecpa1swXVrPRxmaz_Wg0zAlhn
# https://drive.google.com/uc?id=1DomjxpvnO5jC_xTi9x9pu_Lg-_J-hiC4
# https://drive.google.com/uc?id=1rHdr-XuWqoHn8r4jYRfX0dSVwDmBmm6Z
# https://drive.google.com/uc?id=1gXk5Ohob7lkNcjnVXUZfUV7R-EcTaRDG
# https://drive.google.com/uc?id=1Mc4lKgN3e7Nllr_YiJcz-byNm8YagwBL
# https://drive.google.com/uc?id=1NmE1mGFh4k5ktdXe02tCMU-uv4CqKn_n
# https://drive.google.com/uc?id=13MtURI337tI0kE0CRSUZY4Apu9qOPo64
# https://drive.google.com/uc?id=1g7D1CcU6sWTO95VedqhKN5mEuVjdnicY
# https://drive.google.com/uc?id=1myrUCJhXIWCyotz6ISy9tRTnrnqHe-bD
# https://drive.google.com/uc?id=1Lqu1rouut65vuymNnRiBDhoNfqePRt-Y
# https://drive.google.com/uc?id=1jlO5TWSvRNMcCFer0Z4po1g97Ixfti2z
# https://drive.google.com/uc?id=1ZNGGKP7n7rBQPBk9zi1U-NEcJcpC66zi
# https://drive.google.com/uc?id=1JgQ6E7trMyZZnS3EfJWIfMW_oCc6ighO
# https://drive.google.com/uc?id=13xLNcAZC5fycpXFHXBZPSFinC1ELK8Jm
# https://drive.google.com/uc?id=19t7Hh981wqVjpsWTray28BtbR8jQFj9t
# https://drive.google.com/uc?id=1ItVfqYnz0xElY2RUKIHyZqJOTxChVnO0
# https://drive.google.com/uc?id=1dr_1xSXuP89yZhO6R87fhbREgv0xsRFL
# https://drive.google.com/uc?id=1qhje2I2KPaJ5Vgxn-PKmqfT3a68KjoGj
# https://drive.google.com/uc?id=13gjVgeJKc0P3is3w-MSxcWtGim9Iwgev
# https://drive.google.com/uc?id=14nyusdMelGWTQQe-uyS5TcmHWwe8-wfL
# https://drive.google.com/uc?id=1_ugldd9gX5KT8z_c9Pl75y5Z-YcQU3ln
# https://drive.google.com/uc?id=1zE4OTw2gtZ8O5SNwGJAlBnFyEw2XWQdO
# https://drive.google.com/uc?id=1y3Gce2aZyOGcCQYOcItRiSwlWI0Z7dop
# https://drive.google.com/uc?id=1KYe2Liz-VC-eELz2VqIrK1FbL5kOSFKg
# https://drive.google.com/uc?id=1XUOwZOu0RyskFG6m7HLinwNSv3DRJq6t
# https://drive.google.com/uc?id=1OgrJzrcWFOF_K0_r8n16LtXoF4CT8ggW
# https://drive.google.com/uc?id=1LyFNEG8ERmG9XVwieEJNjHyv8fXhUw1g
# https://drive.google.com/uc?id=1VIqx0hCqQ01Zhj0bTo4kjOaQS_Xh0_0b
# https://drive.google.com/uc?id=15_TIFEzB08lKTWSB1BKAJ91DsN9RKfB3
# https://drive.google.com/uc?id=1cxIfksXC7_17WxbH48TwGcMMfg9qjdmz
# https://drive.google.com/uc?id=1m_gmKPm5ZVgK95BXO545HWRH8vs0yHQ2
# https://drive.google.com/uc?id=19DxMTYwcB15uy6tUwdz38buWMroi8cL5
# https://drive.google.com/uc?id=16_dyvQVVNB590XvT_Grk9UxHFUIDIZRZ
# https://drive.google.com/uc?id=15t7kp-onUP2nbBnQEe9SM0-cK28gCXWt
# https://drive.google.com/uc?id=1aI1KfJtsqsZlP_gOPhHBlOIL2zDsjLfg
# https://drive.google.com/uc?id=1VPJIUht_t_eOLmDwWxKFPgTM224zSyyK
# https://drive.google.com/uc?id=16Lh4xXJ4GntNrL6QCtM58KmPP9_WaH-m
# https://drive.google.com/uc?id=1ikYz558oyZpvg-ZeS3cwIv1w9bB8LKmc
# https://drive.google.com/uc?id=1y0VfYPh9BlBkaEmJOYDSZeHjLPgE1psk
# https://drive.google.com/uc?id=11evYPfhKOwoqQS2v9UKY3m90RNAl5Rs2
# https://drive.google.com/uc?id=1O2drtuOnekPC-fsCz1cNe6vFJEtFIZdy
# https://drive.google.com/uc?id=1lO9QUrkkkmgEQd-zXVPJSs95tOCsHGcd
# https://drive.google.com/uc?id=15ASTTRTAizeUMqvuU388AEjHLrgaHr5-
# https://drive.google.com/uc?id=1_qsEHMuQeNbIvA4sAI7-pqej55cdSeCP
# https://drive.google.com/uc?id=1fQQ80aWu-b5ZtVgHVFFca0g3WFqZBK_i
# https://drive.google.com/uc?id=1lEuDq_M2bjm73xa6XXTQxdhN4Mnjkq2o
# https://drive.google.com/uc?id=1qUTLWbQZuiWDyaKlSYEJU09uMXhz5n45
# https://drive.google.com/uc?id=1ik4W7B7LEykOidEaQdLCRIqZ93sMGn0i
# https://drive.google.com/uc?id=1WhgWzYS9WMqMw1N6MsCCnmwzi9aRzXcL
# https://drive.google.com/uc?id=1L-jris074OgxQ8p4aAsS5NGGwLvuVpLu
# https://drive.google.com/uc?id=1Rv2dVR55uIChQVDKjwlJ0RRfJMKx1lE5
# https://drive.google.com/uc?id=1AdlCxTPqIGS85nt2iSIC-nRCmDmteJXh
# https://drive.google.com/uc?id=1HdJh0nTqG7ERg9DhX2psUkjV4vJh4Mvb
# https://drive.google.com/uc?id=1YkqOblngk8H4nIAHh6WxPPFniLYbHcPo
# https://drive.google.com/uc?id=17sayBSDHYu8innzjDkWRmTLHawmHf84b
# https://drive.google.com/uc?id=1sic3-7gyOg1zc1Ru9UglWLHtGFKKWpnp
# https://drive.google.com/uc?id=1L-NvNFeOZ9UD-OVY-o8ndhN7NaKNIFuW
# https://drive.google.com/uc?id=1ZK9gD88yjozaxgX1BYjS3vz_Q0Avfga2
# https://drive.google.com/uc?id=1udDzcDW6QwjdYLmPfhSUjgfbvJ8zul--
# https://drive.google.com/uc?id=1elcA-SSoR9PjghLakifo9ufSmWkBryJw
# https://drive.google.com/uc?id=1FnapROYgMJbMwckjQJnQrgFtdnthjuY2
# https://drive.google.com/uc?id=1BW1r3LwoNQp2wjl-YFg4JVrZk12eiJKI
# https://drive.google.com/uc?id=1hrYoV7Qt8qouJEDmJ4SUEkfeWwGS47lk
# https://drive.google.com/uc?id=15eXZDUIuaNhkbXFnA5aEPRWhRUiScSP2
# https://drive.google.com/uc?id=1sYAVg91dLIOZ6Zj2TG2acovJtzTkOP1H
# https://drive.google.com/uc?id=19qjV752e7mthDwZKg7phVssA7mwjZpgP
# https://drive.google.com/uc?id=1SIM2Xr5XEP3ijeg0JG6qY9e9KAmQoGeZ
# https://drive.google.com/uc?id=1YjQ1xZpEK5FMKXy7k_SlLM-CounenZ3B
# https://drive.google.com/uc?id=1ow7BvqedPXvuk1iB7o4mejO7N0ZG4Vgj
# https://drive.google.com/uc?id=18hMflwDZGwFLWD8TLu72j3ZsOnXWoVoI
# https://drive.google.com/uc?id=17f5nNFyQ4Vj8W5codzBn1FCl69kpK1MW
# https://drive.google.com/uc?id=1rCKyZwqr3VjtOUOGkrEq0S9oPdCa4Lkd
# https://drive.google.com/uc?id=1C29GpHKAtCDzwUMQt8m3SHwFOWDTisxK
# https://drive.google.com/uc?id=1n1B7gesYaJmlCGvKjWW-zbsfMsXixvmN
# https://drive.google.com/uc?id=1Et9qYzidGumej9sphWCn50hXgL_LQ0Kw
# https://drive.google.com/uc?id=1Fp4BJ8Jy5iMKbZ06p-iSbHBsYQ_FxUu-
# https://drive.google.com/uc?id=1VLiiC1sOyDH4pQ48GOfVX9qDteNEwXvM
# https://drive.google.com/uc?id=1kfDnjUAp3fd7W2GCdDxmiv06BES6Eltj
# https://drive.google.com/uc?id=1xGlV7V6o31W0YZKLS5xTyHyPdE4iQfiJ
# https://drive.google.com/uc?id=1Aw-Ax-O8v_dBES1ItuSIekWUZnRiPxFy
# https://drive.google.com/uc?id=1FjThe9sAJFVlRapoq-k-I_K5oe_u9Vry
# https://drive.google.com/uc?id=1n23qbXMV-8guPbz6rKaPtD_BYjMPhKz7
# https://drive.google.com/uc?id=1aYqhlEJ0izOdsCwkHc8ZXydRD6OEwk95
# https://drive.google.com/uc?id=1a3DbZhfeMHXi7ktVunkv6v2wviW7V75i
# https://drive.google.com/uc?id=13RYB8vuVM6kFfa2TWSPkLch2B5W20eeP
# https://drive.google.com/uc?id=1NO0huMLhOtYSj14HBtFI2YYSRF2pZ4Jc
# https://drive.google.com/uc?id=1rS6Zs2qVgJHlc1Rn_HBp3w33b41NmGOi
# https://drive.google.com/uc?id=1aUFUQ0ggPbXxqji8ECKTRbSinm5VsuGa
# https://drive.google.com/uc?id=1y5W47HF_cMBWMAae6Y-IQ56H2dWQY1_P
# https://drive.google.com/uc?id=13jR2q6sUT5FNayMGubnFg0aTFmLw1JDh
# https://drive.google.com/uc?id=1lZspEAJ43lxJ2QzecuphK21_eYmKAZ9J
# https://drive.google.com/uc?id=1bSAUg-FbhwvZ69Ne_flJtrLk3smU1YXZ
# https://drive.google.com/uc?id=1lm5B3hEAqXwikQbTgexqogTwSHUqBHWs
# https://drive.google.com/uc?id=1ooWnjyIbs4j7NG_dlasxOZy_ZRQCtIfT
# https://drive.google.com/uc?id=1rtUlDERhUEiOgDSG2RWZ3tdVrRBtKOs7
# https://drive.google.com/uc?id=1xUS2vlmApkfswyVyqJUUWVk1gaqivGvD
# https://drive.google.com/uc?id=1u4cIaDE9SSa1AXUwChZA6pkWohP38nBJ
# https://drive.google.com/uc?id=10PWGcsv46QlRIfXtF5Jl6O3YrrnGC-eJ
# https://drive.google.com/uc?id=1PdCmKAso6V-V5_aZqIdvmXPqvsuqy6YP
# https://drive.google.com/uc?id=1ycAI9-eFRMlWYEX7tAN6_iruZbR9S4Lt
# https://drive.google.com/uc?id=18Ztm1owxXRyDHhQ4aly_K1YCdAh_L7KO
# https://drive.google.com/uc?id=1shj4K8vYudv6dSWNsME-N1Cq7XoMyaOi
# https://drive.google.com/uc?id=134jqiFVCXOUlNRt2GPElsTZyUeivtUuq
# https://drive.google.com/uc?id=11Qq_qs7Ewy_niQvNz5AH06FLk4QhWqDD
# https://drive.google.com/uc?id=1DKxudm8d9EGdY3s4OKsQ5gur-WQNd_5J
# https://drive.google.com/uc?id=1xfaAjinw5XTVsn_GrcBA_jgFA80UshMk
# https://drive.google.com/uc?id=1vx_v_dB0ncKxhqQUwjGOrrKjktciGVcp
# https://drive.google.com/uc?id=1rgQsSfDTp7YLosuaCwzALY4rMetrS2_b
# https://drive.google.com/uc?id=17VRu16ZpYn3DhK_ogu5W9Mqwp7A7Q5K7
# https://drive.google.com/uc?id=1sUD7L2Pq-yrzBVjbi-rk-uHoYLqI01Ia
# https://drive.google.com/uc?id=1w6IG3wJflCEg_sRLirLv4NxzpELzsrBL
# https://drive.google.com/uc?id=1VXA-yJELYwCk8RU56-KHEQvSZGH3NFT7
# https://drive.google.com/uc?id=1iCvaqJaisI3oub9ODmqk4o7ScAUjX8Q3
# https://drive.google.com/uc?id=1xQYEbTUTX56Kk6VpDLhAM_b9sUJTnLiS
# https://drive.google.com/uc?id=1rhIbePFgXTjO4223aY43LWAorsZ3wYrE
# https://drive.google.com/uc?id=18GPV7lam4qahbx6cdXkqIeqdeOthOWji
# https://drive.google.com/uc?id=1hDET3ybE1Hfx5iMMG7SY6xh_h-dfZjxP
# https://drive.google.com/uc?id=1CsvbpBXrbduSX4zqjZYQc1Klrxt-OVO8
# https://drive.google.com/uc?id=1WR5LZSIjRo5nv41cdUkzB8qB86ZRxDGs
# https://drive.google.com/uc?id=1ZMNxh94WhaUlc0M5un0zeWVsS48LuXVW
# https://drive.google.com/uc?id=1OoV6cmRXOkYUq4v33jo5Q48aXUW1WQL0
# https://drive.google.com/uc?id=1pwSh1Grfm6RBFQykFelttwPCSZTl18mx
# https://drive.google.com/uc?id=1v0yGIyshUlW4b7MXyG202u_2LaJIZgeY
# https://drive.google.com/uc?id=1n2nIWooJSXxUu6wkk80J09y-V8dzAvoL
# https://drive.google.com/uc?id=1yuG2Ko7_yKNIZEx0jz65qOIN5TiKyn3H
# https://drive.google.com/uc?id=1h5m_MuGDNlkqxvM68Ox_1jYejA8mgO3B
# https://drive.google.com/uc?id=1-hqIRtyEdmxfFFzHC64crlcNef5Q7akq
# https://drive.google.com/uc?id=1Nb3HRP5F3KZJCtMCnFW7QmUqg3vdUr1D
# https://drive.google.com/uc?id=1zpq3cddjMDf17UBAhEzZBblQVazIUalD
# https://drive.google.com/uc?id=13PnL5N35FqjXjzorZaSO_OST6VSQACpi
# https://drive.google.com/uc?id=14oE6rHXt6XNlqgP3OL1APZQGNmK8JQYE
# https://drive.google.com/uc?id=1Sf2xNCjVK-Gn6ld_kSvvkHqniZnenJ5b
# https://drive.google.com/uc?id=17pdPc7M2ZF_RETVUwtP4_eRBPpvmLNKq
# https://drive.google.com/uc?id=1MHZRJgzA4oQyTOg7mqjvu0vej4SJJ9Mo
# https://drive.google.com/uc?id=1bLpBLJwbN3TF00zziJl_5ri0T-26hmgw
# https://drive.google.com/uc?id=1HVdqHnhfa9Z7azkQk1Ngec5onZoPkO7T
# https://drive.google.com/uc?id=1wG1Mcdjfx7rp1c7vdLdX32evdVq6q6-h
# https://drive.google.com/uc?id=1oyFn8FVBRuN9ZaHZELYALxn6CXNqEcmr
# https://drive.google.com/uc?id=1rg9H3qFRaxjkE6fSsdeD05BnVY1u2F1M
# https://drive.google.com/uc?id=1pr768bDOrNKjUIGhHxCie5AVvbVdpXWT
# https://drive.google.com/uc?id=1s0LylQPlLbrvVSROIrjQ4StQUchDin71
# https://drive.google.com/uc?id=195JC_NH9LtQpCZ6NRQ3LiIJ0IIg0rf6R
# https://drive.google.com/uc?id=1L1n2UNVRZd2jYY2J6MPq_HuQzaJXdqBo
# https://drive.google.com/uc?id=1fqVteZbs8wcF3SDpXLeRUKOnwblBlQlI
# https://drive.google.com/uc?id=1aATqcKpHo4ghxqzxu2u1R9EdnmY15G2z
# https://drive.google.com/uc?id=1JAEBi2oRs9t9sMghWF6Q7qQUKWYP6OWE
# https://drive.google.com/uc?id=1pehnAAdIa9bNTlomlZIRNxsTG28m0GZM
# https://drive.google.com/uc?id=1eu1P84jWhGkNiiZ6kPa1l7EGCXuUbjU5
# https://drive.google.com/uc?id=1Fz1ALkTbRs4Kq985xIYW9hM29MRA6XKv
# https://drive.google.com/uc?id=1eZxU4jaCHNkl2yoVm0U42M_DATVM0xIQ
# https://drive.google.com/uc?id=1xS9JZyd02EopKaX4cBKWhITfWqjWH-4V
# https://drive.google.com/uc?id=1ZiJ5COiA6Jwbld---RDAJb6_kRduFjHn
# https://drive.google.com/uc?id=1HFf9hT8hI1It4GzJzugtPPsRjMm1djFV
# https://drive.google.com/uc?id=1O_sheNbj9VEuhI-ShlFyWO-AuSE1_Fud
# https://drive.google.com/uc?id=1JiKzkz0-zt9INV0SksGNe0EHULZEJxQr
# https://drive.google.com/uc?id=1vElDOap8eTe71AUGyDt4kpKdyct75rDq
# https://drive.google.com/uc?id=1pBLrwbHmXSAcJrD6ByW73FBH0NmRUakN
# https://drive.google.com/uc?id=11ERL5wniOQLbHtJK-xQuvpn3vngG9W_0
# https://drive.google.com/uc?id=1VB3EzaZyUdN7HFaoYYYCK4vp6j8scv29
# https://drive.google.com/uc?id=1Rh9PwgLjUDU2NcOSTGSQux5PzNT5D9yP
# https://drive.google.com/uc?id=17jKKXQn-RxeZETqA5PaslzSKSe5OuxYl
# https://drive.google.com/uc?id=1oIy_4SSMFUuVtCJx8JsKTyfAlcTwioZ9
# https://drive.google.com/uc?id=1LJpXWe-b_ItKYMR3Mz-28xnzq6wZQdF9
# https://drive.google.com/uc?id=1lJteFyfmRP6gazuqdU-UJ8J5dzRVOrB-
# https://drive.google.com/uc?id=1TVILcTmMeWYQsMWvwI7_pZLhRmSYUx-E
# https://drive.google.com/uc?id=1hkeIutDFdlrtvfy_HPgjm2pa_L8RIyNt
# https://drive.google.com/uc?id=1LvvUxAPKL5j-eKHXeLLmCuUKtjYQrip4
# https://drive.google.com/uc?id=188Dt-1VF1XUO0Ymg7wL8m30g6CsuNW02
# https://drive.google.com/uc?id=1fgF53_w50aeJc73DukiGdnm6zyRU3DZY
# https://drive.google.com/uc?id=1iUpWc89uVB9ruXMPklKPapdsQQ_eYlzS
# https://drive.google.com/uc?id=1RN4VuDSJMHkr7PmWzr8WnmOPMaAreKdu
# https://drive.google.com/uc?id=11gK_VUWLKVKGuEm5iv2_t4VTUHMnZKjQ
# https://drive.google.com/uc?id=1VsNdzX6H8wtuhqCGMfwP_Viotkyvvyyi
# https://drive.google.com/uc?id=1DOa785_eztqL03C3huFQqA6N-ZBC4pum
# https://drive.google.com/uc?id=1XxkV4Wit78WQYkZ6zgTsJqBr5IVhEZd4
# https://drive.google.com/uc?id=1oIE6OYxsDiPcVPqUAde635qxbrPTQboS
# https://drive.google.com/uc?id=1EgOJqAzsMw3VcebhU3jADs0IdZv20tw9
# https://drive.google.com/uc?id=1kEnJPsba_AjUxdjxHO9Qp2GCYeOayGwU

# %%
len(image_urls)
# Out:
# 200

# %%
import json
import random

def write_to_jsonl(prompts, image_urls, max_tokens = 1200):

    # Generate JSONL content
    jsonl_content = []
    for i, url in enumerate(image_urls):
        prompt = random.choice(prompts)
        request = {
            "custom_id": f"request-{i+1}",
            "method": "POST",
            "url": "/v1/chat/completions",
            "body": {
                "model": "gpt-4o",
                "messages": [
                    {
                        "role": "user",
                        "content": [
                            {
                                "type": "text",
                                "text": f"{prompt}"
                            },
                            {
                                "type": "image_url",
                                "image_url": {
                                    "url": f"{url}"
                                }
                            }
                        ]
                    }
                ],
                "max_tokens": max_tokens
            }
        }
        jsonl_content.append(request)

    # Write to JSONL file
    with open("batchinput.jsonl", "w") as f:
        for entry in jsonl_content:
            f.write(json.dumps(entry) + "\n")

    print("batchinput.jsonl file created.")

# Define the prompts for different parts of the extraction
prompts = [
    "Extract only the course information from the attached transcript image, including but not limited to subjects/course codes, grades, credits, and other information. Please then structure it into a table in CSV format. If the image is not a transcript, respond with 'not a transcript'.",
    "Please transcribe only the grade data from the attached transcript image into a CSV format with the appropriate fields. If the image is not a transcript, respond with 'not a transcript'.",
    "From the attached transcript image, extract and organize the course and grade data, along with any other columns, into CSV format. No need to include term data or student basic information. Ensure all data is accurately transcribed and formatted. If the image is not a transcript, respond with 'not a transcript'.",
    "Extract comprehensive course details from the attached transcript image, such as subject codes, course names, grades, and credits. If there are more or other column headers, include them aswell. Organize this data into a table in CSV format. Only extract data relevant to the course information. If the image does not contain a student transcript, respond with 'not a transcript'.",
    "Identify and extract the tabular grade information from the attached transcript image. Transcribe this information into a table in CSV format. If the image is not a transcript, respond with 'not a transcript'.",
    "Extract and transcribe just the course information from the transcript image into a table in CSV format. Include specific fields for the courses, grades, and any other columns available. Ensure all data is formatted correctly. If the image is not a transcript, respond with 'not a transcript'."
]
# Image urls already defined

write_to_jsonl(prompts, image_urls)
# Out:
# batchinput.jsonl file created.

# %%
# Since there is a 90 000 token limit, we need to split our 200 samples into chunks
# Function to split a list into smaller chunks
def split_list(lst, chunk_size):
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

# Path to the existing JSONL file
input_file = "batchinput.jsonl"

# Read the existing JSONL file
with open(input_file, "r") as f:
    lines = f.readlines()

# Number of chunks (in this case, 4)
num_chunks = 4
chunk_size = len(lines) // num_chunks

# Split the lines into chunks
chunks = list(split_list(lines, chunk_size))

# Write each chunk to a new JSONL file
for idx, chunk in enumerate(chunks):
    filename = f"batchinput_part_{idx + 1}.jsonl"
    with open(filename, "w") as f:
        for line in chunk:
            f.write(line)
    print(f"{filename} file created with {len(chunk)} lines.")

print(f"Total lines: {sum(len(chunk) for chunk in chunks)}")
# Out:
# batchinput_part_1.jsonl file created with 50 lines.
# batchinput_part_2.jsonl file created with 50 lines.
# batchinput_part_3.jsonl file created with 50 lines.
# batchinput_part_4.jsonl file created with 50 lines.
# Total lines: 200

# %%
import openai
# Set your OpenAI API key
api_key = 'sk-proj-WMUAiU7RSVuQyXru8yn7T3BlbkFJbqBfbs2i7he2nuGBiqi5'

client = openai.OpenAI(api_key=api_key)

# Upload JSONL file
with open("Input_JSONL/batchinput_part_4.jsonl", "rb") as f:
    batch_input_file = client.files.create(file=f, purpose='batch')

batch_input_file_id = batch_input_file.id
print(f"Batch input file uploaded with ID: {batch_input_file_id}")

# Create batch job
batch = client.batches.create(
    input_file_id=batch_input_file_id,
    endpoint="/v1/chat/completions",
    completion_window="24h",
    metadata={
        "description": "Transcript image processing batch job, part 1."
    }
)

print("Batch job created.")
print(batch)
# Out:
# Batch input file uploaded with ID: file-bYZ3j6BghSm0hMlGBdIwoXRZ
# Batch job created.
# Batch(id='batch_taS6V1TJIjAdEak0AcWvRuuF', completion_window='24h', created_at=1717447199, endpoint='/v1/chat/completions', input_file_id='file-bYZ3j6BghSm0hMlGBdIwoXRZ', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1717533599, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'Transcript image processing batch job, part 1.'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %%
# Check status
client.batches.retrieve("batch_ttxxW6YmmlYT7jkZadQvoNRv")
# Out:
# Batch(id='batch_ttxxW6YmmlYT7jkZadQvoNRv', completion_window='24h', created_at=1717442895, endpoint='/v1/chat/completions', input_file_id='file-DzstArLd1SKLy10KCW68Skfc', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o in organization org-LyCWzHEWOMkZKVa87GQimuOJ. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1717529295, failed_at=1717442917, finalizing_at=None, in_progress_at=None, metadata={'description': 'Transcript image processing batch job'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
